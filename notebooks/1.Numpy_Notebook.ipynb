# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(0, 10, 500)
y = np.cumsum(np.random.randn(500, 6), 0)

# %%
plt.figure(figsize = (12, 7))
plt.plot(x, y)
# Out:
# [<matplotlib.lines.Line2D at 0x7ff2bd6ec9d0>,
#  <matplotlib.lines.Line2D at 0x7ff2bd6ec940>,
#  <matplotlib.lines.Line2D at 0x7ff2bd6edb70>,
#  <matplotlib.lines.Line2D at 0x7ff2bd6edc60>,
#  <matplotlib.lines.Line2D at 0x7ff2bd6edd50>,
#  <matplotlib.lines.Line2D at 0x7ff2bd6ede40>]
