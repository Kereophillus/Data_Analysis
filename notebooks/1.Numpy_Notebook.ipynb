# %% [markdown]
# # <center> NUMPY </center>

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# > ##### Why Numpy?
# > _Numpy provides resource efficient implementations in contrast with vanilla Python_<br>
#     _With Numpy, overheads related to wrapping up artifacts in objects is eliminated_ <br>
#     _Numpy has greatly increased the use cases of Python_ <br>
#     _Note: You trade in simplicity for efficiency._ <br>

# %% [markdown]
# #### Example: Building Data Sets using Numpy

# %% [markdown]
# > Read documentation about function like this: `np.function?`

# %%
np.cumsum?
# Out:
# Signature:       np.cumsum(a, axis=None, dtype=None, out=None)
# Call signature:  np.cumsum(*args, **kwargs)
# Type:            _ArrayFunctionDispatcher
# String form:     <function cumsum at 0x7b7069184c20>
# File:            ~/Projects/Data_Analysis/.DataAnalysisEnv/lib/python3.12/site-packages/numpy/_core/fromnumeric.py
# Docstring:
# Return the cumulative sum of the elements along a given axis.
#
# Parameters
# ----------
# a : array_like
#     Input array.
# axis : int, optional
#     Axis along which the cumulative sum is computed. The default
#     (None) is to compute the cumsum over the flattened array.
# dtype : dtype, optional
#     Type of the returned array and of the accumulator in which the
#     elements are summed.  If `dtype` is not specified, it defaults
#     to the dtype of `a`, unless `a` has an integer dtype with a
#     precision less than that of the default platform integer.  In
#     that case, the default platform integer is used.
# ...

# %%
x = np.linspace(0, 10, 500)
y = np.cumsum(np.random.randn(500, 6), 0)

# %%
plt.figure(figsize = (12, 7))
plt.plot(x, y)
